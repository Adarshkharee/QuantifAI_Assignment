# %%
import pandas as pd
import sqlite3
import os

# %%
#Step 1: Load Raw Data Files (CSV + JSON)
orders = pd.read_csv("orders_unstructured_data.csv")
customers = pd.read_json("customers_messy_data.json")
products = pd.read_json("products_inconsistent_data.json")

# %%
#Step 2: Normalize Column Names
def normalize_columns(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
    return df

orders = normalize_columns(orders)
customers = normalize_columns(customers)
products = normalize_columns(products)

# %%
#Step 3: Preview Top Rows
print("Orders Sample:")
display(orders.head())
print("Customers Sample:")
display(customers.head())
print("Products Sample:")
display(products.head())
# Out:
# Orders Sample:
#     order_id  ord_id  customer_id    cust_id order_date  \
# 0  ORD_00001       1          316  CUST_0316   4/1/2023
# 1  ORD_00002       2           67  CUST_0067  7/28/2023
# 2  ORD_00003       3          373  CUST_0373  7/19/2023
# 3  ORD_00004       4          133  CUST_0133   9/1/2023
# 4  ORD_00005       5          298  CUST_0298   3/3/2023
#
#              order_datetime product_id  item_id  quantity  qty  ...  \
# 0  2023-07-17T02:49:00.000Z   PROD_013      143         7    1  ...
# 1                       NaN   PROD_064      168         7    1  ...
# 2  2023-08-14T17:27:00.000Z   PROD_115       88         7    5  ...
# 3  2023-09-12T11:04:00.000Z   PROD_143      110         4    4  ...
# 4  2023-09-25T19:14:00.000Z   PROD_142      114         9    2  ...
#
#    order_total  shipping_cost    tax  discount      status  order_status  \
# 0       684.81          17.88  17.52      0.00  processing           NaN
# 1       520.20           0.00   4.78     20.78    returned    processing
# 2       359.42          13.51  18.81      0.00     SHIPPED           NaN
# 3       236.93          17.90  40.37      0.00     pending    processing
# 4       568.53          15.82  13.85     11.35   delivered     CANCELLED
#
#    payment_method shipping_address notes tracking_number
# 0      debit_card     4648 Main St   NaN             NaN
# 1   bank_transfer      346 Main St   NaN       TRK209660
# 2     credit_card     8981 Oak Ave   NaN       TRK895514
# 3          paypal     6424 Pine Rd   NaN       TRK350215
# 4      debit_card     8454 Oak Ave   NaN             NaN
#
# [5 rows x 23 columns]
# Customers Sample:
#    customer_id    cust_id            customer_name     full_name  \
# 0            1  CUST_0001                 jane_doe    Bob Wilson
# 1            2  CUST_0002  alice.johnson@email.com  diana.prince
# 2            3  CUST_0003                EVE WHITE  diana.prince
# 3            4  CUST_0004            Charlie Brown  diana.prince
# 4            5  CUST_0005             diana.prince     EVE WHITE
#
#                    email     email_address     phone    phone_number  \
# 0  customer1@example.com  user1@domain.com  555-2322  (555) 818-1484
# 1  customer2@example.com  user2@domain.com      None
# 2  customer3@example.com  user3@domain.com      None
# 3  customer4@example.com  user4@domain.com      None  (555) 150-1781
# 4  customer5@example.com  user5@domain.com      None
#
#            address         city  ...    status  customer_status total_orders  \
# 0     7633 Main St      Houston  ...  INACTIVE          pending           17
# 1    2937 First St  Los Angeles  ...  INACTIVE        suspended           21
# 2    1641 First St      chicago  ...  INACTIVE           ACTIVE           24
# 3  4153 Second Ave          NYC  ...  INACTIVE         INACTIVE           42
# 4  1838 Second Ave     New York  ...    ACTIVE        suspended           16
#
#   total_spent loyalty_points preferred_payment   age  birth_date  gender  \
# 0     1375.96            805              None  37.0  1990-03-04       M
# 1     1966.01            630              None  39.0        None   Other
# 2     3421.32             96            paypal  59.0  1993-12-24    Male
# 3     3683.84            544            paypal  71.0  1961-07-14       F
# 4     2865.06            190              cash  76.0        None       M
#
#    segment
# 0      vip
# 1  premium
# 2  regular
# 3     None
# 4      vip
#
# [5 rows x 25 columns]
# Products Sample:
#   product_id  item_id product_name    item_name                description  \
# 0   PROD_001        1    Product 1  Item 1 Name  Description for product 1
# 1   PROD_002        2    Product 2  Item 2 Name  Description for product 2
# 2   PROD_003        3    Product 3  Item 3 Name  Description for product 3
# 3   PROD_004        4    Product 4  Item 4 Name  Description for product 4
# 4   PROD_005        5    Product 5  Item 5 Name  Description for product 5
#
#    category product_category    brand manufacturer   price  ...  color  size  \
# 0  clothing      electronics  BRAND-C         None  314.49  ...  White
# 1  clothing         clothing  brand_b      BRAND-C   50.37  ...  Black     S
# 2    Sports            Books   brandE         None  152.16  ...  Green    XL
# 3  clothing             Toys   brandE       brandE   44.31  ...  Green    XL
# 4  CLOTHING      Electronics  BRAND-C      BRAND-C  445.60  ...    Red    XL
#
#    stock_quantity stock_level reorder_level supplier_id  created_date  \
# 0             277         254            14        None    2022-12-11
# 1             938          38            23        None    2020-02-23
# 2             120         441            32      SUP_05    2020-04-03
# 3             997         262            45      SUP_11    2023-12-21
# 4             673         406            36      SUP_07    2023-11-04
#
#                last_updated  is_active rating
# 0  2023-02-03T18:30:00.000Z       true    0.3
# 1  2023-02-23T18:30:00.000Z      false    1.9
# 2  2023-11-27T18:30:00.000Z      False    4.3
# 3  2023-01-02T18:30:00.000Z          0    3.9
# 4  2023-04-24T18:30:00.000Z       true    4.1
#
# [5 rows x 24 columns]

# %%
#Step 4: Missing Values Check
print("Missing values:")
print("Orders:\n", orders.isnull().sum())
print("Customers:\n", customers.isnull().sum())
print("Products:\n", products.isnull().sum())
# Out:
# Missing values:
# Orders:
#  order_id              0
# ord_id                0
# customer_id           0
# cust_id               0
# order_date           94
# order_datetime      195
# product_id            0
# item_id               0
# quantity              0
# qty                   0
# unit_price            0
# price                 0
# total_amount          0
# order_total           0
# shipping_cost         0
# tax                   0
# discount              0
# status              146
# order_status        130
# payment_method        0
# shipping_address      0
# notes               793
# tracking_number     417
# dtype: int64
# Customers:
#  customer_id            0
# cust_id                0
# customer_name          0
# full_name              0
# email                 86
# email_address          0
# phone                317
# phone_number           0
# address                0
# city                   0
# state                  0
# zip_code             148
# postal_code            0
# registration_date    100
# reg_date               0
# status                62
# customer_status       78
# total_orders           0
# total_spent            0
# loyalty_points         0
# preferred_payment     96
# age                  195
# birth_date           320
# gender                74
# segment               98
# dtype: int64
# Products:
#  product_id           0
# item_id              0
# product_name         0
# item_name            0
# description         58
# category             0
# product_category     0
# brand               21
# manufacturer        25
# price                0
# list_price           0
# cost                 0
# weight              91
# dimensions           0
# color               23
# size                22
# stock_quantity       0
# stock_level          0
# reorder_level        0
# supplier_id         59
# created_date        37
# last_updated         0
# is_active            0
# rating              70
# dtype: int64

# %%
#Step 5: Data Types Check
print("Data types:")
print("Orders:\n", orders.dtypes)
print("Customers:\n", customers.dtypes)
print("Products:\n", products.dtypes)
# Out:
# Data types:
# Orders:
#  order_id             object
# ord_id                int64
# customer_id           int64
# cust_id              object
# order_date           object
# order_datetime       object
# product_id           object
# item_id               int64
# quantity              int64
# qty                   int64
# unit_price          float64
# price               float64
# total_amount        float64
# order_total         float64
# shipping_cost       float64
# tax                 float64
# discount            float64
# status               object
# order_status         object
# payment_method       object
# shipping_address     object
# notes                object
# tracking_number      object
# dtype: object
# Customers:
#  customer_id            int64
# cust_id               object
# customer_name         object
# full_name             object
# email                 object
# email_address         object
# phone                 object
# phone_number          object
# address               object
# city                  object
# state                 object
# zip_code             float64
# postal_code           object
# registration_date     object
# reg_date              object
# status                object
# customer_status       object
# total_orders           int64
# total_spent          float64
# loyalty_points         int64
# preferred_payment     object
# age                  float64
# birth_date            object
# gender                object
# segment               object
# dtype: object
# Products:
#  product_id           object
# item_id               int64
# product_name         object
# item_name            object
# description          object
# category             object
# product_category     object
# brand                object
# manufacturer         object
# price               float64
# list_price          float64
# cost                float64
# weight              float64
# dimensions           object
# color                object
# size                 object
# stock_quantity        int64
# stock_level           int64
# reorder_level         int64
# supplier_id          object
# created_date         object
# last_updated         object
# is_active            object
# rating              float64
# dtype: object

# %%
#Step 6: Drop Duplicates
orders = orders.drop_duplicates()
customers = customers.drop_duplicates()
products = products.drop_duplicates()

# %%
#Step 7: Convert Dates
orders['order_date'] = pd.to_datetime(orders['order_date'], errors='coerce')
if 'created_date' in products.columns:
    products['created_date'] = pd.to_datetime(products['created_date'], errors='coerce')
if 'last_updated' in products.columns:
    products['last_updated'] = pd.to_datetime(products['last_updated'], errors='coerce')

# %%
#Step 8: Convert Numeric Fields
for col in ['amount', 'price', 'cost', 'list_price', 'rating']:
    if col in orders.columns:
        orders[col] = pd.to_numeric(orders[col], errors='coerce')
    if col in products.columns:
        products[col] = pd.to_numeric(products[col], errors='coerce')

# %%
#Step 9: Standardize Booleans (e.g., is_active)
def standardize_boolean(val):
    if str(val).lower() in ['1', 'true', 'yes']:
        return True
    elif str(val).lower() in ['0', 'false', 'no']:
        return False
    return pd.NA

if 'is_active' in products.columns:
    products['is_active'] = products['is_active'].apply(standardize_boolean)

# %%
#Step 10: Drop rows with missing important IDs
orders = orders.dropna(subset=['order_id', 'customer_id'])
customers = customers.dropna(subset=['customer_id'])
products = products.dropna(subset=['product_id'])

# %%
#Step 11: Save Cleaned Files (optional)
os.makedirs("cleaned_data", exist_ok=True)
orders.to_csv("cleaned_data/orders_clean.csv", index=False)
customers.to_json("cleaned_data/customers_clean.json", orient='records', indent=2)
products.to_json("cleaned_data/products_clean.json", orient='records', indent=2)

# %%
#Step 12: Load into SQLite Database
conn = sqlite3.connect("ecommerce.db")
orders.to_sql("orders", conn, if_exists="replace", index=False)
customers.to_sql("customers", conn, if_exists="replace", index=False)
products.to_sql("products", conn, if_exists="replace", index=False)
conn.commit()
conn.close()

print("All data cleaned and loaded into 'ecommerce.db' successfully!")
# Out:
# All data cleaned and loaded into 'ecommerce.db' successfully!
